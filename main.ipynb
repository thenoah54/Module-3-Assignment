# %%
import requests
from collections import Counter
import pandas as pd
import numpy as np
from sklearn.metrics import DistanceMetric
from sklearn.metrics.pairwise import cosine_similarity

# %%
url = 'https://graphql.anilist.co'

# %%
def find_data(year):
    query = """
    query ($year: Int, $page: Int, $perPage: Int) {
      Page(page: $page, perPage: $perPage) {
        media(seasonYear: $year, type: ANIME, sort: POPULARITY_DESC) {
          id
          title {
            romaji
            english
          }
          genres
          season
          seasonYear
          averageScore
          episodes
          popularity
        }
      }
    }
    """

    variables = {
        'year': year,
        'page': 1,
        'perPage': 50
    }

    response = requests.post(url, json={'query': query, 'variables': variables})
    data = response.json()
    anime_data = data['data']['Page']['media']

    df = pd.json_normalize(anime_data)

    # Keep useful columns
    df = df[['title.romaji', 'title.english', 'genres', 'season', 'seasonYear', 'popularity','averageScore']]
    df = df.dropna(subset=['genres'])  # Remove entries without genre data

    # Create a simplified title column
    df['title'] = df['title.english'].fillna(df['title.romaji'])
    df = df.dropna(subset=['title']).reset_index(drop=True)

    # Normalize score (optional)
    df['averageScore'] = df['averageScore'].fillna(df['averageScore'].mean())
    df['score_norm'] = (df['averageScore'] - df['averageScore'].min()) / (df['averageScore'].max() - df['averageScore'].min())

    return df

# %%
def get_anime_data_range(start_year, end_year):
    all_years = []
    for y in range(start_year, end_year + 1):
        try:
            year_df = find_data(y)
            all_years.append(year_df)
        except Exception as e:
            print(f"Error fetching {y}: {e}")
    combined_df = pd.concat(all_years, ignore_index=True)
    return combined_df

# %%
# test
# df = find_data(2025)
# df.head(15)
# anime_df = get_anime_data_range(2018, 2024)
# anime_df = get_anime_data_range(2005, 2025)
# anime_df.sort_values(by='popularity', ascending=False).head(50)
# Out:
#                                           title.romaji  \
# 400                                 Shingeki no Kyojin
# 700                                   Kimetsu no Yaiba
# 50                                          DEATH NOTE
# 750                                     Jujutsu Kaisen
# 550                              Boku no Hero Academia
# 300                               HUNTER×HUNTER (2011)
# 500                                      One Punch Man
# 450                                        Tokyo Ghoul
# 600                        Shingeki no Kyojin Season 2
# 200      Hagane no Renkinjutsushi: FULLMETAL ALCHEMIST
# 350                                   Sword Art Online
# 551                                     Kimi no Na wa.
# 552                                     Koe no Katachi
# 650                        Shingeki no Kyojin Season 3
# 601                            Boku no Hero Academia 2
# 701                              Yakusoku no Neverland
# 800               Shingeki no Kyojin: The Final Season
# 501                                 Ansatsu Kyoushitsu
# 553                                     Mob Psycho 100
# 451                            Shigatsu wa Kimi no Uso
# 554                            Boku dake ga Inai Machi
# 651                            Boku no Hero Academia 3
# 100                                 NARUTO: Shippuuden
# 702                 Shingeki no Kyojin Season 3 Part 2
# 555              Re:Zero kara Hajimeru Isekai Seikatsu
# 301                                        Steins;Gate
# 452                                          Haikyuu!!
# 850                                       Chainsaw Man
# 652  Seishun Buta Yarou wa Bunny Girl Senpai no Yum...
# 602                                       Black Clover
# 453                                           Noragami
# 454                                    No Game No Life
# 703  Kaguya-sama wa Kokurasetai: Tensaitachi no Ren...
# 704                                          Dr. STONE
# 150                                          Toradora!
# 653                                  Violet Evergarden
# 851                                         SPY×FAMILY
# 455                                     Akame ga Kill!
# 705                            Boku no Hero Academia 4
# 456                                  Nanatsu no Taizai
# 706                                       VINLAND SAGA
# 556             Kono Subarashii Sekai ni Shukufuku wo!
# 801                                           Horimiya
# 457                         Kiseijuu: Sei no Kakuritsu
# 751                 Kimetsu no Yaiba: Mugen Ressha-hen
# 654                              Darling in the Franxx
# 51                     Code Geass: Hangyaku no Lelouch
# 502                                       Death Parade
# 302                                     Ao no Exorcist
# 351                      JoJo no Kimyou na Bouken (TV)
#
#                                          title.english  \
# 400                                    Attack on Titan
# 700                     Demon Slayer: Kimetsu no Yaiba
# 50                                          Death Note
# 750                                     JUJUTSU KAISEN
# 550                                   My Hero Academia
# 300                             Hunter x Hunter (2011)
# 500                                      One-Punch Man
# 450                                        Tokyo Ghoul
# 600                           Attack on Titan Season 2
# 200                   Fullmetal Alchemist: Brotherhood
# 350                                   Sword Art Online
# 551                                         Your Name.
# 552                                     A Silent Voice
# 650                           Attack on Titan Season 3
# 601                          My Hero Academia Season 2
# 701                             The Promised Neverland
# 800                       Attack on Titan Final Season
# 501                            Assassination Classroom
# 553                                     Mob Psycho 100
# 451                                  Your lie in April
# 554                                             ERASED
# 651                          My Hero Academia Season 3
# 100                                  Naruto: Shippuden
# 702                    Attack on Titan Season 3 Part 2
# 555           Re:ZERO -Starting Life in Another World-
# 301                                        Steins;Gate
# 452                                           HAIKYU!!
# 850                                       Chainsaw Man
# 652         Rascal Does Not Dream of Bunny Girl Senpai
# 602                                       Black Clover
# 453                                           Noragami
# 454                                   No Game, No Life
# 703                           Kaguya-sama: Love is War
# 704                                          Dr. STONE
# 150                                          Toradora!
# 653                                  Violet Evergarden
# 851                                       SPY x FAMILY
# 455                                     Akame ga Kill!
# 705                          My Hero Academia Season 4
# 456                              The Seven Deadly Sins
# 706                                       Vinland Saga
# 556  KONOSUBA -God's blessing on this wonderful world!
# 801                                           Horimiya
# 457                               Parasyte -the maxim-
# 751  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...
# 654                              DARLING in the FRANXX
# 51                Code Geass: Lelouch of the Rebellion
# 502                                       Death Parade
# 302                                      Blue Exorcist
# 351                      JoJo's Bizarre Adventure (TV)
#
#                                                 genres  season  seasonYear  \
# 400                  [Action, Drama, Fantasy, Mystery]  SPRING        2013
# 700  [Action, Adventure, Drama, Fantasy, Supernatural]  SPRING        2019
# 50    [Mystery, Psychological, Supernatural, Thriller]    FALL        2006
# 750                      [Action, Drama, Supernatural]    FALL        2020
# 550                        [Action, Adventure, Comedy]  SPRING        2016
# 300                       [Action, Adventure, Fantasy]    FALL        2011
# 500             [Action, Comedy, Sci-Fi, Supernatural]    FALL        2015
# 450  [Action, Drama, Horror, Mystery, Psychological...  SUMMER        2014
# 600                  [Action, Drama, Fantasy, Mystery]  SPRING        2017
# 200                [Action, Adventure, Drama, Fantasy]  SPRING        2009
# 350              [Action, Adventure, Fantasy, Romance]  SUMMER        2012
# 551                     [Drama, Romance, Supernatural]  SUMMER        2016
# 552                    [Drama, Romance, Slice of Life]  SUMMER        2016
# 650                  [Action, Drama, Fantasy, Mystery]  SUMMER        2018
# 601                        [Action, Adventure, Comedy]  SPRING        2017
# 701  [Drama, Fantasy, Horror, Mystery, Psychologica...  WINTER        2019
# 800                  [Action, Drama, Fantasy, Mystery]  WINTER        2021
# 501              [Action, Comedy, Drama, Supernatural]  WINTER        2015
# 553  [Action, Comedy, Drama, Psychological, Slice o...  SUMMER        2016
# 451             [Drama, Music, Romance, Slice of Life]    FALL        2014
# 554  [Drama, Mystery, Psychological, Supernatural, ...  WINTER        2016
# 651                 [Action, Adventure, Comedy, Drama]  SPRING        2018
# 100  [Action, Adventure, Comedy, Drama, Fantasy, Su...  WINTER        2007
# 702                  [Action, Drama, Fantasy, Mystery]  SPRING        2019
# 555  [Action, Adventure, Drama, Fantasy, Psychologi...  SPRING        2016
# 301           [Drama, Psychological, Sci-Fi, Thriller]  SPRING        2011
# 452                            [Comedy, Drama, Sports]  SPRING        2014
# 850              [Action, Drama, Horror, Supernatural]    FALL        2022
# 652  [Comedy, Drama, Mystery, Psychological, Romanc...    FALL        2018
# 602               [Action, Adventure, Comedy, Fantasy]    FALL        2017
# 453          [Action, Adventure, Comedy, Supernatural]  WINTER        2014
# 454                [Adventure, Comedy, Ecchi, Fantasy]  SPRING        2014
# 703    [Comedy, Psychological, Romance, Slice of Life]  WINTER        2019
# 704                [Action, Adventure, Comedy, Sci-Fi]  SUMMER        2019
# 150            [Comedy, Drama, Romance, Slice of Life]    FALL        2008
# 653                    [Drama, Fantasy, Slice of Life]  WINTER        2018
# 851      [Action, Comedy, Slice of Life, Supernatural]  SPRING        2022
# 455  [Action, Adventure, Drama, Fantasy, Horror, Ps...  SUMMER        2014
# 705         [Action, Adventure, Comedy, Drama, Sci-Fi]    FALL        2019
# 456  [Action, Adventure, Comedy, Ecchi, Fantasy, Su...    FALL        2014
# 706                         [Action, Adventure, Drama]  SUMMER        2019
# 556                [Adventure, Comedy, Ecchi, Fantasy]  WINTER        2016
# 801                   [Comedy, Romance, Slice of Life]  WINTER        2021
# 457     [Action, Drama, Horror, Psychological, Sci-Fi]    FALL        2014
# 751  [Action, Adventure, Drama, Fantasy, Mystery, S...    FALL        2020
# 654  [Action, Drama, Mecha, Psychological, Romance,...  WINTER        2018
# 51            [Action, Drama, Mecha, Sci-Fi, Thriller]    FALL        2006
# 502  [Drama, Mystery, Psychological, Supernatural, ...  WINTER        2015
# 302                    [Action, Fantasy, Supernatural]  SPRING        2011
# 351                  [Action, Adventure, Supernatural]    FALL        2012
#
#      popularity  averageScore  \
# 400      912336            85
# 700      866659            82
# 50       830515            84
# 750      820501            84
# 550      769451            76
# 300      734799            89
# 500      682230            83
# 450      651244            75
# 600      644109            84
# 200      634329            90
# 350      633716            69
# 551      622026            85
# 552      612730            88
# 650      601519            85
# 601      585230            79
# 701      569561            83
# 800      561090            86
# 501      555954            79
# 553      546223            84
# 451      537230            84
# 554      536534            81
# 651      535850            79
# 100      534875            82
# 702      534281            89
# 555      529039            81
# 301      521879            89
# 452      519905            83
# 850      502917            83
# 652      501628            81
# 602      497800            79
# 453      487973            77
# 454      487621            77
# 703      487130            83
# 704      482249            81
# 150      481036            78
# 653      479973            85
# 851      479836            83
# 455      475432            72
# 705      472015            78
# 456      471894            73
# 706      454336            87
# 556      454071            79
# 801      449685            81
# 457      445372            81
# 751      444269            84
# 654      438253            68
# 51       427829            85
# 502      421009            80
# 302      418375            72
# 351      416115            77
#
#                                                  title  score_norm
# 400                                    Attack on Titan    0.930233
# 700                     Demon Slayer: Kimetsu no Yaiba    0.781250
# 50                                          Death Note    0.980769
# 750                                     JUJUTSU KAISEN    0.880000
# 550                                   My Hero Academia    0.538462
# 300                             Hunter x Hunter (2011)    1.000000
# 500                                      One-Punch Man    0.741935
# 450                                        Tokyo Ghoul    0.500000
# 600                           Attack on Titan Season 2    0.848485
# 200                   Fullmetal Alchemist: Brotherhood    1.000000
# 350                                   Sword Art Online    0.310345
# 551                                         Your Name.    0.884615
# 552                                     A Silent Voice    1.000000
# 650                           Attack on Titan Season 3    1.000000
# 601                          My Hero Academia Season 2    0.696970
# 701                             The Promised Neverland    0.812500
# 800                       Attack on Titan Final Season    0.921053
# 501                            Assassination Classroom    0.612903
# 553                                     Mob Psycho 100    0.846154
# 451                                  Your lie in April    0.950000
# 554                                             ERASED    0.730769
# 651                          My Hero Academia Season 3    0.760000
# 100                                  Naruto: Shippuden    0.916667
# 702                    Attack on Titan Season 3 Part 2    1.000000
# 555           Re:ZERO -Starting Life in Another World-    0.730769
# 301                                        Steins;Gate    1.000000
# 452                                           HAIKYU!!    0.900000
# 850                                       Chainsaw Man    0.777778
# 652         Rascal Does Not Dream of Bunny Girl Senpai    0.840000
# 602                                       Black Clover    0.696970
# 453                                           Noragami    0.600000
# 454                                   No Game, No Life    0.600000
# 703                           Kaguya-sama: Love is War    0.812500
# 704                                          Dr. STONE    0.750000
# 150                                          Toradora!    0.709677
# 653                                  Violet Evergarden    1.000000
# 851                                       SPY x FAMILY    0.777778
# 455                                     Akame ga Kill!    0.350000
# 705                          My Hero Academia Season 4    0.656250
# 456                              The Seven Deadly Sins    0.400000
# 706                                       Vinland Saga    0.937500
# 556  KONOSUBA -God's blessing on this wonderful world!    0.653846
# 801                                           Horimiya    0.789474
# 457                               Parasyte -the maxim-    0.800000
# 751  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...    0.880000
# 654                              DARLING in the FRANXX    0.320000
# 51                Code Geass: Lelouch of the Rebellion    1.000000
# 502                                       Death Parade    0.645161
# 302                                      Blue Exorcist    0.451613
# 351                      JoJo's Bizarre Adventure (TV)    0.586207

# %%
# jaccard similarity
def jaccard_similarity(genres1, genres2):
    set1, set2 = set(genres1), set(genres2)
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union > 0 else 0

# %%
# get similarity 
def compute_similarity(df, weight_genre=0.8, weight_score=0.2):
    n = len(df)
    sim_matrix = np.zeros((n, n))

    for i in range(n):
        for j in range(n):
            genre_sim = jaccard_similarity(df['genres'][i], df['genres'][j])
            score_sim = 1 - abs(df['score_norm'][i] - df['score_norm'][j])  
            sim_matrix[i, j] = (weight_genre * genre_sim) + (weight_score * score_sim)
    return sim_matrix

# %%
# get similiarty
def top_similar(df, sim_matrix, title, n=10):
    if title not in df['title'].values:
        print(f"'{title}' not found in dataset.")
        return

    idx = df.index[df['title'] == title][0]
    similar_indices = sim_matrix[idx].argsort()[::-1][1:n+1]  
    result = df.iloc[similar_indices][['title', 'genres', 'score_norm']]
    return result

# %%
anime_df = get_anime_data_range(2005, 2025)
df = anime_df.sort_values(by='popularity', ascending=False)
sim_matrix = compute_similarity(df)
# Out:
# Error fetching 2023: 'NoneType' object is not subscriptable
# Error fetching 2024: 'NoneType' object is not subscriptable
# Error fetching 2025: 'NoneType' object is not subscriptable

# %%
queries = ['Demon Slayer: Kimetsu no Yaiba', 'Golden Time', 'Free! -Iwatobi Swim Club-']

# %%
anime = queries[0]
print(anime)
top_similar(df, sim_matrix, anime).sort_values(by='score_norm', ascending=False)
# Out:
# Demon Slayer: Kimetsu no Yaiba
#                                             title  \
# 677             A Place Further Than the Universe
# 71                Kenichi: The Mightiest Disciple
# 17                         Strawberry Marshmallow
# 651                     My Hero Academia Season 3
# 69                                       Air Gear
# 459  JoJo's Bizarre Adventure: Stardust Crusaders
# 886          The Quintessential Quintuplets Movie
# 239                   Tenchi Muyo! War on Geminar
# 355              Love, Chunibyo & Other Delusions
# 149                                   Zombie Loan
#
#                                       genres  score_norm
# 677               [Adventure, Comedy, Drama]    0.960000
# 71                          [Action, Comedy]    0.846154
# 17                   [Comedy, Slice of Life]    0.833333
# 651       [Action, Adventure, Comedy, Drama]    0.760000
# 69           [Action, Comedy, Ecchi, Sports]    0.711538
# 459        [Action, Adventure, Supernatural]    0.700000
# 886  [Comedy, Drama, Romance, Slice of Life]    0.592593
# 239  [Action, Comedy, Ecchi, Fantasy, Mecha]    0.540541
# 355  [Comedy, Drama, Romance, Slice of Life]    0.517241
# 149           [Action, Horror, Supernatural]    0.361111

# %%
anime = queries[1]
print(anime)
top_similar(df, sim_matrix, anime).sort_values(by='score_norm', ascending=False)
# Out:
# Golden Time
#                                                  title  \
# 863                                   BOCCHI THE ROCK!
# 734  Fate/stay night [Heaven's Feel] II. lost butte...
# 703                           Kaguya-sama: Love is War
# 457                               Parasyte -the maxim-
# 277                Black Lagoon: Roberta's Blood Trail
# 106                                         Lucky☆Star
# 404                                Beyond the Boundary
# 442  Love, Chunibyo & Other Delusions: Glimmering.....
# 326             Hanasaku Iroha ~Blossoms for Tomorrow~
# 201                                         Fairy Tail
#
#                                                 genres  score_norm
# 863                     [Comedy, Music, Slice of Life]    0.925926
# 734  [Action, Fantasy, Psychological, Romance, Supe...    0.843750
# 703    [Comedy, Psychological, Romance, Slice of Life]    0.812500
# 457     [Action, Drama, Horror, Psychological, Sci-Fi]    0.800000
# 277               [Action, Adventure, Drama, Thriller]    0.741935
# 106                            [Comedy, Slice of Life]    0.722222
# 404  [Action, Drama, Fantasy, Slice of Life, Supern...    0.674419
# 442                   [Comedy, Romance, Slice of Life]    0.651163
# 326                     [Comedy, Drama, Slice of Life]    0.612903
# 201               [Action, Adventure, Comedy, Fantasy]    0.486486

# %%
anime = queries[2]
print(anime)
top_similar(df, sim_matrix, anime).sort_values(by='score_norm', ascending=False)
# Out:
# Free! -Iwatobi Swim Club-
#                        title  \
# 480  Ping Pong the Animation
# 624     Land of the Lustrous
# 723                    given
# 210                  Redline
# 209         Eden of the East
# 228                   Canaan
# 483            World Trigger
# 270        Demon King Daimao
# 299        Cat Planet Cuties
# 449          Diabolik Lovers
#
#                                                 genres  score_norm
# 480                     [Drama, Psychological, Sports]    1.000000
# 624   [Action, Drama, Fantasy, Mystery, Psychological]    0.818182
# 723             [Drama, Music, Romance, Slice of Life]    0.781250
# 210                  [Action, Romance, Sci-Fi, Sports]    0.756757
# 209  [Drama, Mystery, Psychological, Romance, Sci-F...    0.567568
# 228                     [Action, Sci-Fi, Supernatural]    0.405405
# 483                                   [Action, Sci-Fi]    0.350000
# 270                   [Action, Comedy, Ecchi, Fantasy]    0.225806
# 299                   [Comedy, Ecchi, Romance, Sci-Fi]    0.193548
# 449             [Drama, Horror, Romance, Supernatural]    0.000000
